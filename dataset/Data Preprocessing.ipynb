# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("2..Places.csv" )

# %%
df
# Out:
#        sno             state    City  \
# 0        1  HIMACHAL PRADESH  Manali
# 1        2  HIMACHAL PRADESH  Manali
# 2        3  HIMACHAL PRADESH  Manali
# 3        4  HIMACHAL PRADESH  Manali
# 4        5  HIMACHAL PRADESH  Manali
# ...    ...               ...     ...
# 2984  2985               NaN  Poovar
# 2985  2986               NaN  Poovar
# 2986  2987               NaN  Poovar
# 2987  2988               NaN  Poovar
# 2988  2989               NaN  Poovar
#
#                                                Place Best_time_to_visit  \
# 0            1. Capture the Sceneries of Old Manali        October-June
# 1      2. Engage in the Adventures of Solang Valley        October-June
# 2                               3. Jogini Waterfall        October-June
# 3                                 4. Hadimba Temple        October-June
# 4                                   5. Rohtang Pass        October-June
# ...                                              ...                ...
# ...

# %%
print(df.shape)
# Out:
# (2989, 7)

# %%
df.isnull().sum()
# Out:
# sno                      0
# state                 2939
# City                     0
# Place                    0
# Best_time_to_visit    2939
# Distance                16
# Place_desc               0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['sno', 'state', 'City', 'Place', 'Best_time_to_visit', 'Distance',
#        'Place_desc'],
#       dtype='object')

# %%
df.loc[df.City=='Leh Ladakh', 'state'] = 'Ladakh'

# %%
df[df['City']=='Leh Ladakh']
df.tail()
# Out:
#        sno state    City                     Place Best_time_to_visit  \
# 2984  2985   NaN  Poovar   5. The Fishing Village                 NaN
# 2985  2986   NaN  Poovar               6. Cruises                 NaN
# 2986  2987   NaN  Poovar         7. Kovalam Beach                 NaN
# 2987  2988   NaN  Poovar             8. Boat Race                 NaN
# 2988  2989   NaN  Poovar              9. Ayurveda                 NaN
#
#                        Distance  \
# 2984   11 km  from city center
# 2985    1 km  from city center
# 2986   12 km  from city center
# 2987    2 km  from city center
# 2988    7 km  from city center
#
#                                              Place_desc
# 2984   A village lying in the proximity of Poovar is...
# 2985   Amid the crystal clear ripples of water and s...
# 2986   A captivating beach with nature's beauty at i...
# 2987   Adrenaline rushing snake boat races are a spe...
# 2988   Based on a universal principle of faith that ...

# %%
df['City'].unique()
# Out:
# array(['Manali', 'Leh Ladakh', 'Coorg', 'Andaman', 'Lakshadweep', 'Goa',
#        'Udaipur', 'Srinagar', 'Gangtok', 'Munnar', 'Varkala',
#        'Mcleodganj', 'Rishikesh', 'Alleppey', 'Darjeeling', 'Nainital',
#        'Shimla', 'Ooty', 'Jaipur', 'Lonavala', 'Mussoorie', 'Kodaikanal',
#        'Dalhousie', 'Pachmarhi', 'Varanasi', 'Mumbai', 'Agra', 'Kolkata',
#        'Jodhpur', 'Bangalore', 'Amritsar', 'Delhi', 'Jaisalmer',
#        'Mount Abu', 'Wayanad', 'Hyderabad', 'Pondicherry', 'Khajuraho',
#        'Chennai', 'Vaishno Devi', 'Ajanta and Ellora Caves', 'Haridwar',
#        'Kanyakumari', 'Pune', 'Kochi', 'Ahmedabad', 'Mysore',
#        'Chandigarh', 'Hampi', 'Gulmarg', 'Almora', 'Shirdi', 'Auli',
#        'Madurai', 'Amarnath', 'Bodh Gaya', 'Mahabaleshwar',
#        'Visakhapatnam', 'Kasol', 'Nashik', 'Tirupati', 'Ujjain',
#        'Jim Corbett National Park', 'Gwalior', 'Mathura', 'Alibaug',
#        'Rameshwaram', 'Vrindavan', 'Coimbatore', 'Lucknow', 'Digha',
# ...

# %%
df.loc[(df.City=='Almora') | (df.City=='Nainital') | (df.City=='Rishikesh') | (df.City=='Jim Corbett National Park') | (df.City=='Dehradun') | (df.City=='Haridwar')| (df.City=='Auli') | (df.City=='Mussoorie'), 'state'] = 'Uttarakhand'
df.loc[(df.City == 'Poovar')| (df.City=='Munnar') | (df.City=='Varkala') | (df.City=='Alleppey')  | (df.City=='Wayanad') | (df.City=='Kochi') | (df.City=='Kovalam') | (df.City=='')  | (df.City=='') ,'state'] = 'Kerela'
df.loc[(df.City == 'Lavasa')| (df.City=='Lonavala') | (df.City=='Mumbai') | (df.City=='Ajanta and Ellora Caves')  | (df.City=='Pune') | (df.City=='Shirdi')  | (df.City=='Mahabaleshwar')| (df.City=='Nashik') | (df.City=='Alibaug')  | (df.City=='Matheran')| (df.City=='Khandala') | (df.City=='Aurangabad') ,'state'] = 'Maharashtra'
df.loc[(df.City == 'Nahan')| (df.City=='Mcleodganj') | (df.City=='Shimla') | (df.City=='Dalhousie')| (df.City=='Kasol')  | (df.City=='Dharamshala') | (df.City=='Kasauli') ,'state'] = 'Himanchal Pradesh'
df.loc[(df.City == 'Varanasi') | (df.City=='Agra') | (df.City=='Mathura') | (df.City=='Vrindavan')  | (df.City=='Lucknow')  ,'state'] = 'Uttar Pradesh'
df.loc[(df.City == 'Udaipur') | (df.City=='Jaipur') | (df.City=='Jodhpur') | (df.City=='Jaisalmer')| (df.City=='Ajmer')| (df.City=='Ranthambore') | (df.City=='Chittorgarh')| (df.City=='Pushkar')| (df.City=='Bikaner')| (df.City=='Mount Abu') ,'state'] = 'Rajasthan'
df.loc[(df.City == 'Pachmarhi') | (df.City=='Khajuraho') | (df.City=='Ujjain') | (df.City=='Gwalior') ,'state'] = 'Madhya Pradesh'
df.loc[(df.City == 'Coorg') | (df.City=='Bangalore') | (df.City=='Mysore') | (df.City=='Hampi')  | (df.City=='Madikeri')  | (df.City=='Shimoga (Shivamogga)')  ,'state'] = 'Karnataka'
df.loc[(df.City == 'Andaman') ,'state'] = 'Andaman and Nicobar '
df.loc[(df.City == 'Lakshadweep') ,'state'] = 'Lakshadweep Island'
df.loc[(df.City == 'Goa')  ,'state'] = 'Goa'
df.loc[(df.City == 'Srinagar') | (df.City=='Vaishno Devi') | (df.City=='Gulmarg') | (df.City=='Amarnath')  | (df.City=='Jammu')  ,'state'] = 'Jammu and Kashmir'
df.loc[(df.City == 'Gangtok') ,'state'] = 'Sikkim'
df.loc[(df.City == 'Darjeeling') | (df.City=='Kolkata') | (df.City=='Digha') | (df.City=='Kalimpong')  ,'state'] = 'West Bengal'
df.loc[(df.City == 'Ooty') | (df.City=='Kodaikanal') | (df.City=='Chennai') | (df.City=='Kanyakumari')  | (df.City=='Madurai') | (df.City=='Rameshwaram')  | (df.City=='Coimbatore')| (df.City=='Thanjavur')  | (df.City=='Hogenakkal') ,'state'] = 'Tamil Nadu'
df.loc[(df.City == 'Amritsar') | (df.City=='Chandigarh') ,'state'] = 'Punjab'
df.loc[(df.City == 'Delhi')  ,'state'] = 'Delhi'
df.loc[(df.City == 'Hyderabad') | (df.City=='Visakhapatnam') | (df.City=='Tirupati')  ,'state'] = 'AndraPradesh'
df.loc[(df.City == 'Pondicherry') ,'state'] = 'Puducherry'
df.loc[(df.City == 'Ahmedabad')  ,'state'] = 'Gujarat'
df.loc[(df.City == 'Bodh Gaya') ,'state'] = 'Bihar'
df.loc[(df.City == 'Agartala')  ,'state'] = 'Tripura'
df.loc[(df.City == 'Bhubaneswar') | (df.City=='Puri')  ,'state'] = 'Odisha'
df.loc[(df.City == 'Cherrapunji') ,'state'] = 'Meghalaya'

# %%
df[df['state'].isnull()]['City'].unique()
# Out:
# array([], dtype=object)

# %%
df[df['state'] == 'Maharashtra'].head(100)
# Out:
#        sno        state                     City  \
# 774    775  Maharashtra                 Lonavala
# 775    776  Maharashtra                 Lonavala
# 776    777  Maharashtra                 Lonavala
# 777    778  Maharashtra                 Lonavala
# 778    779  Maharashtra                 Lonavala
# ...    ...          ...                      ...
# 1557  1558  Maharashtra  Ajanta and Ellora Caves
# 1558  1559  Maharashtra  Ajanta and Ellora Caves
# 1559  1560  Maharashtra  Ajanta and Ellora Caves
# 1560  1561  Maharashtra  Ajanta and Ellora Caves
# 1561  1562  Maharashtra  Ajanta and Ellora Caves
#
#                                   Place Best_time_to_visit  \
# 774                    1. Tiger's Leap                 NaN
# 775                   2. Rajmachi Fort                 NaN
# 776                  3. Imagica Adlabs                 NaN
# 777                    4. Aamby Valley                 NaN
# 778                   5. Lonavala Lake                 NaN
# ...

# %%
df['state'].unique()
# Out:
# array(['HIMACHAL PRADESH', 'Ladakh', 'Karnataka', 'Andaman and Nicobar ',
#        'Lakshadweep Island', 'Goa', 'Rajasthan', 'Jammu and Kashmir',
#        'Sikkim', 'Kerela', 'Himanchal Pradesh', 'Uttarakhand',
#        'West Bengal', 'Tamil Nadu', 'Maharashtra', 'Madhya Pradesh',
#        'Uttar Pradesh', 'Punjab', 'Delhi', 'AndraPradesh', 'Puducherry',
#        'Gujarat', 'Bihar', 'Tripura', 'Odisha', 'Meghalaya'], dtype=object)

# %%
df.head()
# Out:
#    sno             state    City  \
# 0    1  HIMACHAL PRADESH  Manali
# 1    2  HIMACHAL PRADESH  Manali
# 2    3  HIMACHAL PRADESH  Manali
# 3    4  HIMACHAL PRADESH  Manali
# 4    5  HIMACHAL PRADESH  Manali
#
#                                             Place Best_time_to_visit  \
# 0         1. Capture the Sceneries of Old Manali        October-June
# 1   2. Engage in the Adventures of Solang Valley        October-June
# 2                            3. Jogini Waterfall        October-June
# 3                              4. Hadimba Temple        October-June
# 4                                5. Rohtang Pass        October-June
#
#                     Distance  \
# 0    2 km  from city center
# 1    8 km  from city center
# 2    4 km  from city center
# 3    1 km  from city center
# 4   16 km  from city center
#
#                                           Place_desc
# 0   On the other side of the Manalsu river is a p...
# 1   Solang Valley is one of the most popular tour...
# ...

# %%
# df1 = pd.read_csv("C:/Users/shivi/OneDrive/Desktop/project2/dataset/2..Places.csv" )
df1=df

# %%
df2 = pd.read_csv("3..City.csv")

# %%
df2.head(5)
# Out:
#           City  Best_time_to_visit
# 0       Manali        October-June
# 1   Leh Ladakh         JulyOctober
# 2        Coorg      September-June
# 3      Andaman       October-March
# 4  Lakshadweep  September-February

# %%
df2[df2['Best_time_to_visit'] == 'September-June']
# Out:
#     City Best_time_to_visit
# 2  Coorg     September-June

# %%
df2[df2['Best_time_to_visit'] == 'October-May'].head(50)
# Out:
#        City Best_time_to_visit
# 34  Wayanad        October-May

# %%
df.loc[(df.City == 'Gangtok')| (df.City=='Varkala')| (df.City=='Alleppey')| (df.City=='Darjeeling')| (df.City=='Darjeeling')| (df.City=='Nainital')| (df.City=='Lonavala')| (df.City=='Mussoorie')| (df.City=='Dalhousie')| (df.City=='Pachmarhi')| (df.City=='Agra')| (df.City=='Kolkata')| (df.City=='Jodhpur')| (df.City=='Bangalore')| (df.City=='Jaisalmer')| (df.City=='Mount Abu')| (df.City=='Hyderabad')| (df.City=='Pondicherry')| (df.City=='Khajuraho')| (df.City=='Chennai')| (df.City=='Vaishno Devi	')| (df.City=='Ajanta and Ellora Caves')| (df.City=='Kanyakumari')| (df.City=='Pune')| (df.City=='Kochi')| (df.City=='Ahmedabad')| (df.City=='Kanha National Park')| (df.City=='Mysore')| (df.City=='Chandigarh')| (df.City=='Hampi')| (df.City=='Gulmarg')| (df.City=='Almora')| (df.City=='Shirdi')| (df.City=='Auli')| (df.City=='Madurai')| (df.City=='Amarnath')| (df.City=='Bodh Gaya')| (df.City=='Visakhapatnam')| (df.City=='Ujjain')| (df.City=='Jim Corbett National Park')| (df.City=='Gwalior')| (df.City=='Mathura')| (df.City=='Jog Falls')| (df.City=='Alibaug')| (df.City=='Rameshwaram')| (df.City=='Vrindavan')| (df.City=='Coimbatore')| (df.City=='Lucknow')| (df.City=='Digha')| (df.City=='Dharamshala')| (df.City=='Kovalam')| (df.City=='Bangalore')| (df.City=='Vaishno Devi')| (df.City=='Mahabaleshwar')| (df.City=='Nashik')| (df.City=='Madikeri')| (df.City=='Matheran')| (df.City=='Ranthambore')| (df.City=='Agartala')| (df.City=='Khandala')| (df.City=='Kalimpong')| (df.City=='Thanjavur')| (df.City=='Bhubaneswar')| (df.City=='Ajmer')| (df.City=='Aurangabad')| (df.City=='Jammu')| (df.City=='Dehradun')| (df.City=='Puri')| (df.City=='Cherrapunji')| (df.City=='Bikaner')| (df.City=='Shimoga (Shivamogga)')| (df.City=='Hogenakkal')| (df.City=='Kasauli')| (df.City=='Pushkar')| (df.City=='Chittorgarh')| (df.City=='Nahan')| (df.City=='Lavasa')| (df.City=='Poovar') ,'Best_time_to_visit'] = 'All Year'
df.loc[(df.City == 'Manali')| (df.City=='Mcleodganj')| (df.City=='Ooty')| (df.City=='Kodaikanal')| (df.City=='Kasol') ,'Best_time_to_visit'] = 'October-June'
df.loc[(df.City == 'Leh Ladakh'),'Best_time_to_visit'] = 'July-October'
df.loc[(df.City == 'Coorg'),'Best_time_to_visit'] = 'September-June'
df.loc[(df.City == 'Andaman')| (df.City=='Udaipur')| (df.City=='Varanasi')| (df.City=='Amritsar')| (df.City=='Delhi'),'Best_time_to_visit'] = 'October-March'
df.loc[(df.City == 'Lakshadweep'),'Best_time_to_visit'] = 'September-February'
df.loc[(df.City == 'Goa'),'Best_time_to_visit'] = 'November-February'
df.loc[(df.City == 'Srinagar'),'Best_time_to_visit'] = 'April-October'
df.loc[(df.City == 'Munnar')| (df.City=='Tirupati'),'Best_time_to_visit'] = 'September-March'
df.loc[(df.City == 'Rishikesh'),'Best_time_to_visit'] = 'September-June'
df.loc[(df.City == 'Shimla'),'Best_time_to_visit'] = 'March-June'
df.loc[(df.City == 'Jaipur'),'Best_time_to_visit'] = 'November-March'
df.loc[(df.City == 'Mumbai')| (df.City=='Haridwar'),'Best_time_to_visit'] = 'October-February'
df.loc[(df.City == 'Wayanad'),'Best_time_to_visit'] = 'October-May'

# %%
df[df['Best_time_to_visit'].isnull()]['City'].unique()
# Out:
# array([], dtype=object)

# %%
df[df['City'] == 'Haridwar']
# Out:
#        sno        state      City                              Place  \
# 1567  1568  Uttarakhand  Haridwar                    1. Ganga Aarti
# 1568  1569  Uttarakhand  Haridwar                   2. Har Ki Pauri
# 1569  1570  Uttarakhand  Haridwar             3. Chandi Devi Temple
# 1570  1571  Uttarakhand  Haridwar              4. Mansa Devi Temple
# 1571  1572  Uttarakhand  Haridwar      5. Chilla Wildlife Sanctuary
# 1572  1573  Uttarakhand  Haridwar                    6. Shanti Kunj
# 1573  1574  Uttarakhand  Haridwar             7. Bharat Mata Mandir
# 1574  1575  Uttarakhand  Haridwar          8. Daksha Mahadev Temple
# 1575  1576  Uttarakhand  Haridwar            9. Patanjali Yog Peeth
# 1576  1577  Uttarakhand  Haridwar             10. Sapt Rishi Ashram
# 1577  1578  Uttarakhand  Haridwar          11. Ma Anandamayi Ashram
# 1578  1579  Uttarakhand  Haridwar                    12. Pawan Dham
# 1579  1580  Uttarakhand  Haridwar           13. Vaishno Devi Temple
# ...

# %%
df.head(100)
# Out:
#     sno             state        City  \
# 0     1  HIMACHAL PRADESH      Manali
# 1     2  HIMACHAL PRADESH      Manali
# 2     3  HIMACHAL PRADESH      Manali
# 3     4  HIMACHAL PRADESH      Manali
# 4     5  HIMACHAL PRADESH      Manali
# ..  ...               ...         ...
# 95   96            Ladakh  Leh Ladakh
# 96   97            Ladakh  Leh Ladakh
# 97   98            Ladakh  Leh Ladakh
# 98   99            Ladakh  Leh Ladakh
# 99  100            Ladakh  Leh Ladakh
#
#                                              Place Best_time_to_visit  \
# 0          1. Capture the Sceneries of Old Manali        October-June
# 1    2. Engage in the Adventures of Solang Valley        October-June
# 2                             3. Jogini Waterfall        October-June
# 3                               4. Hadimba Temple        October-June
# 4                                 5. Rohtang Pass        October-June
# ..                                             ...                ...
# ...

# %%
# df.to_csv('TourProjectUpdated1.csv')

# %%
df[df['Best_time_to_visit'].isnull()]['City'].unique()
# Out:
# array([], dtype=object)

# %%
df
# Out:
#        sno             state    City  \
# 0        1  HIMACHAL PRADESH  Manali
# 1        2  HIMACHAL PRADESH  Manali
# 2        3  HIMACHAL PRADESH  Manali
# 3        4  HIMACHAL PRADESH  Manali
# 4        5  HIMACHAL PRADESH  Manali
# ...    ...               ...     ...
# 2984  2985            Kerela  Poovar
# 2985  2986            Kerela  Poovar
# 2986  2987            Kerela  Poovar
# 2987  2988            Kerela  Poovar
# 2988  2989            Kerela  Poovar
#
#                                                Place Best_time_to_visit  \
# 0            1. Capture the Sceneries of Old Manali        October-June
# 1      2. Engage in the Adventures of Solang Valley        October-June
# 2                               3. Jogini Waterfall        October-June
# 3                                 4. Hadimba Temple        October-June
# 4                                   5. Rohtang Pass        October-June
# ...                                              ...                ...
# ...

# %%
df.isnull().sum()
# Out:
# sno                    0
# state                  0
# City                   0
# Place                  0
# Best_time_to_visit     0
# Distance              16
# Place_desc             0
# dtype: int64

# %%
df[df['Distance'].isnull()]
# Out:
#        sno              state                     City  \
# 1555  1556        Maharashtra  Ajanta and Ellora Caves
# 1556  1557        Maharashtra  Ajanta and Ellora Caves
# 1557  1558        Maharashtra  Ajanta and Ellora Caves
# 1558  1559        Maharashtra  Ajanta and Ellora Caves
# 1559  1560        Maharashtra  Ajanta and Ellora Caves
# 1560  1561        Maharashtra  Ajanta and Ellora Caves
# 1561  1562        Maharashtra  Ajanta and Ellora Caves
# 1562  1563        Maharashtra  Ajanta and Ellora Caves
# 1563  1564        Maharashtra  Ajanta and Ellora Caves
# 1564  1565        Maharashtra  Ajanta and Ellora Caves
# 1565  1566        Maharashtra  Ajanta and Ellora Caves
# 1566  1567        Maharashtra  Ajanta and Ellora Caves
# 1994  1995  Jammu and Kashmir                 Amarnath
# 1995  1996  Jammu and Kashmir                 Amarnath
# 1996  1997  Jammu and Kashmir                 Amarnath
# 1997  1998  Jammu and Kashmir                 Amarnath
#
# ...

# %%
df["Distance"].fillna("5 km from city center", inplace = True)

# %%
df[df['Distance'].isnull()]
# Out:
# Empty DataFrame
# Columns: [sno, state, City, Place, Best_time_to_visit, Distance, Place_desc]
# Index: []

# %%
df.isnull().sum()
# Out:
# sno                   0
# state                 0
# City                  0
# Place                 0
# Best_time_to_visit    0
# Distance              0
# Place_desc            0
# dtype: int64

# %%
df.to_csv('TourProjectUpdated.csv')

# %%
df
# Out:
#        sno             state    City  \
# 0        1  HIMACHAL PRADESH  Manali
# 1        2  HIMACHAL PRADESH  Manali
# 2        3  HIMACHAL PRADESH  Manali
# 3        4  HIMACHAL PRADESH  Manali
# 4        5  HIMACHAL PRADESH  Manali
# ...    ...               ...     ...
# 2984  2985            Kerela  Poovar
# 2985  2986            Kerela  Poovar
# 2986  2987            Kerela  Poovar
# 2987  2988            Kerela  Poovar
# 2988  2989            Kerela  Poovar
#
#                                                Place Best_time_to_visit  \
# 0            1. Capture the Sceneries of Old Manali        October-June
# 1      2. Engage in the Adventures of Solang Valley        October-June
# 2                               3. Jogini Waterfall        October-June
# 3                                 4. Hadimba Temple        October-June
# 4                                   5. Rohtang Pass        October-June
# ...                                              ...                ...
# ...

# %%
dfa = df.reindex(columns = df.columns.tolist() + ['URL'])

# %%
dfa.isnull().sum()
# Out:
# sno                      0
# state                    0
# City                     0
# Place                    0
# Best_time_to_visit       0
# Distance                 0
# Place_desc               0
# URL                   2989
# dtype: int64

# %%
# df = pd.read_csv("TourProjectUpdated1.csv" )

# %%
df
# Out:
#        sno             state    City  \
# 0        1  HIMACHAL PRADESH  Manali
# 1        2  HIMACHAL PRADESH  Manali
# 2        3  HIMACHAL PRADESH  Manali
# 3        4  HIMACHAL PRADESH  Manali
# 4        5  HIMACHAL PRADESH  Manali
# ...    ...               ...     ...
# 2984  2985            Kerela  Poovar
# 2985  2986            Kerela  Poovar
# 2986  2987            Kerela  Poovar
# 2987  2988            Kerela  Poovar
# 2988  2989            Kerela  Poovar
#
#                                                Place Best_time_to_visit  \
# 0            1. Capture the Sceneries of Old Manali        October-June
# 1      2. Engage in the Adventures of Solang Valley        October-June
# 2                               3. Jogini Waterfall        October-June
# 3                                 4. Hadimba Temple        October-June
# 4                                   5. Rohtang Pass        October-June
# ...                                              ...                ...
# ...

# %%
df["Distance"].fillna("5 km from city center", inplace = True)

# %%
df.isnull().sum()
# Out:
# sno                   0
# state                 0
# City                  0
# Place                 0
# Best_time_to_visit    0
# Distance              0
# Place_desc            0
# dtype: int64
